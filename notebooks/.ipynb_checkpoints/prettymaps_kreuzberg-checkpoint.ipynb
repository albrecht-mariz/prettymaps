# %%
#testing notebook
import prettymaps
import matplotlib
#from matplotlib.font_manager import FontProperties
#from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
fig, ax = plt.subplots(figsize = (20, 20), constrained_layout = True)
plot = prettymaps.plot(
    (52.4987351,13.4152121),
    radius = 1000,
    # Matplotlib axis
    ax = ax,
    #axes.set_xlim(0,100)
    layers = {
        "green": {
            "tags": {
                "landuse": "grass",
                "natural": ["island", "wood"],
                "leisure": "park"
            }
        },
        "forest": {
            "tags": {
                "landuse": "forest"
            }
        },
        "water": {
            "tags": {
                "natural": ["water", "bay"]
            }
        },
        "parking": {
            "tags": {
                "amenity": "parking",
                "highway": "pedestrian",
                "man_made": "pier"
            }
        },
        "streets": {
            "width": {
                "motorway": 3,
                "trunk": 3,
                "primary": 2.5,
                "secondary": 3,
                "tertiary": 2,
                "residential": 1.5,
            }
        },
        "building": {
            "tags": {"building": True},
        },
    },
    style = {
        "background": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "hatch": "ooo...",
        },
        "perimeter": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "lw": 0,
            "hatch": "ooo...",
        },
        "green": {
            "fc": "#bcb46d", #wes
            "ec": "#2F3737",
            "lw": 1,
        },
        "forest": {
            "fc": "#bcb46d", #wes
            "ec": "#2F3737",
            "lw": 1,
        },
        "water": {
            "fc": "#d0e4e2", #wes
            "ec": "#2F3737",
            "hatch": "ooo...",
            "hatch_c": "#85c9e6",
            "lw": 1,
        },
        "parking": {
            "fc": "#F2F4CB",
            "ec": "#2F3737",
            "lw": 1,
        },
        "streets": {
            "fc": "#2F3737",
            "ec": "#475657",
            "alpha": 1,
            "lw": 0,
        },
        "building": {
            "palette": [
                "#e9ba4e", #wes
                "#E9724C",
                "#e0a295"#wes
            ],
            "ec": "#2F3737",
            "lw": 0.5,
        }
    }
)

# Change background color
plot.fig.patch.set_facecolor('#e9ba4e') #wes
# Add title
plot.ax.set_title(
    'Kreuzberg',
    fontproperties = FontProperties(
        fname = '../assets/DancingScript-VariableFont_wght.ttf',
        size = 100
    )
)
plt.savefig('../prints/kreuzberg.png')
# Out:
# C:\Users\acmar\miniconda3\envs\prettymaps\lib\site-packages\prettymaps\draw.py:979: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 100>()
#       2 plot = prettymaps.plot(
#       3     (52.4987351,13.4152121),
#       4     radius = 1000,
#    (...)
#      96     }
#      97 )
#      99 # Change background color
# --> 100 plot.fig.patch.set_facecolor('#e9ba4e') #wes
#     101 # Add title
#     102 plot.ax.set_title(
#     103     'Kreuzberg',
#     104     fontproperties = FontProperties(
#    (...)
#     107     )
#     108 )
#
# AttributeError: 'NoneType' object has no attribute 'patch'
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
